# %% [markdown]
# # Assignment 7: Data Visualization
#
# ## Overview
# This assignment covers the essential tools for data visualization: matplotlib fundamentals, seaborn statistical plots, pandas plotting, and visualization best practices.
#
# ## Setup

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# Set style
plt.style.use('default')
sns.set_style('whitegrid')

# Create output directory
os.makedirs('output', exist_ok=True)

# %% [markdown]
# ## Question 1: matplotlib Fundamentals
#
# ### Part 1.1: Basic Figures and Subplots
#
# **TODO: Create a figure with 2x2 subplots showing different plot types**

# %%
# Create sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(-x/5)
y4 = np.log(x + 1)

# TODO: Create a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# TODO: Plot on each subplot
# Top-left: Sine wave
# Top-right: Cosine wave  
# Bottom-left: Exponential decay
# Bottom-right: Logarithmic function
axes[0, 0].plot(x, y1)
axes[0, 1].plot(x, y2)
axes[1, 0].plot(x, y3)
axes[1, 1].plot(x, y4)

# TODO: Add titles and labels to each subplot
axes[0, 0].set_title('Sine Wave')
axes[0, 0].set_xlabel('X Values')
axes[0, 0].set_ylabel('Y Values')
axes[0, 1].set_title('Cosine Wave')
axes[0, 1].set_xlabel('X Values')
axes[0, 1].set_ylabel('Y Values')
axes[1, 0].set_title('Exponential decay')
axes[1, 0].set_xlabel('X Values')
axes[1, 0].set_ylabel('Y Values')
axes[1, 1].set_title('Logarithmic function')
axes[1, 1].set_xlabel('X Values')
axes[1, 1].set_ylabel('Y Values')
# TODO: Add grid to each subplot
axes[0, 0].grid(True)
axes[0, 1].grid(True)
axes[1, 0].grid(True)
axes[1, 1].grid(True)
# TODO: Use tight_layout() to prevent overlapping
plt.tight_layout()
plt.savefig('output/q1_matplotlib_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Part 1.2: Plot Customization
#
# **TODO: Create a customized line plot with multiple series**

# %%
# Create sample data
x = np.linspace(0, 10, 50)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)

# TODO: Create a figure with custom styling
fig, ax = plt.subplots(figsize=(10, 6))

# TODO: Plot three lines with different styles
# Line 1: Solid line, blue color, label 'sin(x)'
ax.plot(x, y1, linestyle='-', color='blue', label='sin(x)')
# Line 2: Dashed line, red color, label 'cos(x)'  
ax.plot(x, y2, linestyle='--', color='red', label='cos(x)')
# Line 3: Dotted line, green color, label 'sin(x)*cos(x)'
ax.plot(x, y3, linestyle=':', color='green', label='sin(x)*cos(x)')

# TODO: Add title, xlabel, ylabel
ax.set_title('Trigonometric Functions')
# TODO: Add legend
ax.legend()
# TODO: Add grid with transparency
ax.grid(True, alpha=0.3)
# TODO: Set appropriate axis limits
ax.set_xlim([0, 10])
ax.set_ylim([-1.1, 1.1])

plt.tight_layout()
plt.savefig('output/q1_multi_panel.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Part 1.3: Different Plot Types
#
# **TODO: Create a comprehensive visualization with multiple plot types**

# %%
# Create sample data
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 56, 12, 78]
x_scatter = np.random.randn(100)
y_scatter = 2 * x_scatter + np.random.randn(100)
hist_data = np.random.normal(0, 1, 1000)

# TODO: Create a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Bar chart
axes[0, 0].bar(categories, values, color=['red', 'orange', 'darkblue', 'green', 'blue'], edgecolor = "black")
axes[0, 0].grid(True, alpha=0.3)
# TODO: Top-right: Scatter plot
axes[0, 1].scatter(x_scatter, y_scatter, color='pink', alpha=0.9, edgecolor='black')
axes[0, 1].grid(True, linestyle = "--", alpha=0.3)
# TODO: Bottom-left: Histogram
axes[1, 0].hist(hist_data, color='teal', edgecolor='white', alpha=0.7, bins = 30)
axes[1, 0].grid(True, linestyle = ':', alpha = 0.9)
# TODO: Bottom-right: Pie chart
axes[1, 1].pie(values, labels=categories, colors= ['lightblue', 'salmon', 'gold', 'purple', 'lime'], autopct='%1.1f%%', startangle=110)

# TODO: Add appropriate titles and labels
axes[0, 0].set_title('Bar Chart', fontsize = 14, fontweight = "bold")
axes[0, 0].set_xlabel('Categories', fontsize = 14, fontweight = "bold")
axes[0, 0].set_ylabel('Frequency', fontsize = 14, fontweight = "bold")
axes[0, 1].set_title('Scatter Plot', color = "darkblue")
axes[0, 1].set_xlabel('X Values', color = "darkblue")
axes[0, 1].set_ylabel('Y Values', color = "darkblue")
axes[1, 0].set_title('Histogram', fontstyle = "italic")
axes[1, 0].set_xlabel('Value Bins', fontstyle = "italic")
axes[1, 0].set_ylabel('Frequency', fontstyle = "italic")
axes[1, 1].set_title('Pie Chart', family= "serif")
axes[1, 1].set_xlabel('Percentage', family= "serif")

# TODO: Customize colors and styles
# TODO: Save the plot as 'output/q1_matplotlib_plots.png'

plt.tight_layout()
plt.savefig('output/q1_multi_panel.png', dpi=300, bbox_inches='tight')
# plt.savefig('output/q1_matplotlib_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Question 2: seaborn Statistical Visualization
#
# ### Part 2.1: Load and Explore Data

# %%
# Load the sales data
sales_df = pd.read_csv('data/sales_data.csv')
customer_df = pd.read_csv('data/customer_data.csv')
product_df = pd.read_csv('data/product_data.csv')

# Merge data for analysis
merged_df = sales_df.merge(customer_df, on='customer_id').merge(product_df, on='product_id')

print("Data shape:", merged_df.shape)
print("\nColumns:", merged_df.columns.tolist())
print("\nFirst few rows:")
print(merged_df.head())
# Out:
# Data shape: (1000, 19)
#
# Columns: ['transaction_id', 'customer_id', 'product_id', 'quantity', 'unit_price_x', 'total_amount', 'transaction_date', 'store_location', 'customer_name', 'age', 'gender', 'city', 'state', 'registration_date', 'product_name', 'category', 'brand', 'unit_price_y', 'stock_quantity']
#
# First few rows:
#   transaction_id customer_id product_id  quantity  unit_price_x  total_amount  \
# 0          T0001       C0103       P040        10    229.359978   2293.599785
# 1          T0002       C0180       P083         3     75.794677    227.384031
# 2          T0003       C0093       P042         5    479.387719   2396.938597
# 3          T0004       C0015       P041         5    269.533265   1347.666324
# 4          T0005       C0107       P006         4    128.527714    514.110856
#
#   transaction_date store_location customer_name  age gender         city  \
# 0       2025-10-09          South  Customer 103   23      F       Dallas
# 1       2025-07-21          North  Customer 180   45      M       Dallas
# 2       2025-06-25           East   Customer 93   70      M  Los Angeles
# 3       2025-07-27          South   Customer 15   35      F  San Antonio
# 4       2025-08-02          South  Customer 107   39      F      Houston
#
#   state registration_date product_name       category    brand  unit_price_y  \
# 0    IL        2025-07-26   Product 40       Clothing  Brand E    230.048472
# 1    TX        2025-07-03   Product 83          Books  Brand C    385.510134
# 2    OH        2025-09-25   Product 42    Electronics  Brand C    289.744456
# 3    CA        2025-08-30   Product 41  Home & Garden  Brand A    293.030410
# 4    NC        2025-07-04    Product 6       Clothing  Brand B    242.636813
#
#    stock_quantity
# 0              52
# 1              78
# 2              70
# 3              32
# 4              39

# %% [markdown]
# ### Part 2.2: Statistical Plots
#
# **TODO: Create statistical visualizations with seaborn**

# %%
# TODO: Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Box plot of total_amount by store_location
sns.boxplot(x='store_location', y='total_amount', data=merged_df, ax=axes[0, 0], palette="Set2", fliersize=4, linewidth = 1, notch= True)     
# TODO: Top-right: Violin plot of total_amount by category
sns.violinplot(x='category', y='total_amount', data=merged_df, ax=axes[0, 1], palette="Pastel1", inner = "quartile",
    linewidth=1)
# TODO: Bottom-left: Scatter plot of quantity vs total_amount with hue by gender
sns.scatterplot(x='quantity', y='total_amount', data= merged_df, hue = 'gender', ax = axes[1, 0], alpha=0.7, edgecolor='w', s=80, palette={'M':'#2ca02c','F':'#d62728'},)
# TODO: Bottom-right: Histogram of total_amount with kde overlay
sns.histplot(data = merged_df, x = "total_amount", kde=True, ax=axes[1, 1], color='red', bins = 30, edgecolor='white', alpha = 0.8)

# TODO: Add appropriate titles and labels
axes[0, 0].set_title('Total Transaction Amount by Store Location', fontsize=13, fontweight='bold')
axes[0,0].set_xlabel('Store Location')
axes[0,0].set_ylabel('Total Transaction Amount ($)')
axes[0, 0].grid(True, linestyle='--', alpha=0.6)
axes[0, 1].set_title('Total Transaction Amount by Product Category', fontsize=13, fontweight='bold')
axes[0, 1].set_xlabel('Product Category')
axes[0, 1].set_ylabel('Total Transaction Amount ($)')  
axes[0, 1].grid(True, linestyle='--', alpha=0.6)
axes[1, 0].set_title('Product Quantity vs Total Transaction Amount ($)', fontsize=13, fontweight='bold')
axes[1, 0].set_xlabel('Product Quantity')
axes[1, 0].set_ylabel('Total Transaction Amount ($)')
axes[1, 0].grid(True, linestyle='--', alpha=0.6)
axes[1, 1].set_title('Distribution of Total Transaction Amount ($)', fontsize=13, fontweight='bold')
axes[1, 1].set_xlabel('Total Transaction Amount ($)')
axes[1, 1].set_ylabel('Frequency')
axes[1, 1].grid(True, linestyle='--', alpha=0.6)
# TODO: Customize colors and styling
# TODO: Save the plot as 'output/q2_seaborn_plots.png'

plt.tight_layout()
plt.savefig('output/q2_seaborn_plots.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/fz/lz55mbm51216f101cqgbdzlh0000gn/T/ipykernel_78539/2835251633.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='store_location', y='total_amount', data=merged_df, ax=axes[0, 0], palette="Set2", fliersize=4, linewidth = 1, notch= True)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/audreysu/p3/lib/python3.10/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /var/folders/fz/lz55mbm51216f101cqgbdzlh0000gn/T/ipykernel_78539/2835251633.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='category', y='total_amount', data=merged_df, ax=axes[0, 1], palette="Pastel1", inner = "quartile",

# %% [markdown]
# ### Part 2.3: Correlation Analysis
#
# **TODO: Create a correlation heatmap**

# %%
# TODO: Select numeric columns for correlation analysis
# First, explore the merged data to see what columns are available
print("Available columns:", merged_df.columns.tolist())
print("Data types:")
print(merged_df.dtypes)

# TODO: Select only the numeric columns that exist for correlation analysis
# Hint: After merging, pandas adds _x and _y suffixes to duplicate column names
numeric_cols = ["quantity", "unit_price_x", "total_amount", "age", "unit_price_y", "stock_quantity"]  # Fill this with the appropriate column names

# TODO: Calculate correlation matrix
correlation_matrix = merged_df[numeric_cols].corr()
print(correlation_matrix)

# TODO: Create heatmap with seaborn
sns.heatmap(correlation_matrix, annot = True, fmt = ".2f", linewidths=0.5, cmap='coolwarm', cbar_kws={"shrink": .8, "label":"Correlation"})

# TODO: Add title and customize appearance
plt.title('Correlation Heatmap of Numeric Features of Dataset', fontsize=13, fontweight='bold')
# TODO: Save the plot as 'output/q2_correlation_heatmap.png'

plt.tight_layout()
plt.savefig('output/q2_correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Available columns: ['transaction_id', 'customer_id', 'product_id', 'quantity', 'unit_price_x', 'total_amount', 'transaction_date', 'store_location', 'customer_name', 'age', 'gender', 'city', 'state', 'registration_date', 'product_name', 'category', 'brand', 'unit_price_y', 'stock_quantity']
# Data types:
# transaction_id        object
# customer_id           object
# product_id            object
# quantity               int64
# unit_price_x         float64
# total_amount         float64
# transaction_date      object
# store_location        object
# customer_name         object
# age                    int64
# gender                object
# city                  object
# state                 object
# registration_date     object
# product_name          object
# category              object
# brand                 object
# unit_price_y         float64
# stock_quantity         int64
# dtype: object
#                 quantity  unit_price_x  total_amount       age  unit_price_y  \
# quantity        1.000000      0.015208      0.630910 -0.031109      0.005272
# unit_price_x    0.015208      1.000000      0.701893 -0.042189     -0.014586
# total_amount    0.630910      0.701893      1.000000 -0.060204     -0.018226
# age            -0.031109     -0.042189     -0.060204  1.000000      0.032024
# unit_price_y    0.005272     -0.014586     -0.018226  0.032024      1.000000
# stock_quantity  0.018123      0.002488      0.009639  0.022856     -0.100658
#
#                 stock_quantity
# quantity              0.018123
# unit_price_x          0.002488
# total_amount          0.009639
# age                   0.022856
# unit_price_y         -0.100658
# stock_quantity        1.000000

# %% [markdown]
# ## Question 3: pandas Plotting and Data Exploration
#
# ### Part 3.1: Time Series Visualization
#
# **TODO: Create time series plots with pandas**

# %%
# TODO: Convert transaction_date to datetime
merged_df['transaction_date'] = pd.to_datetime(merged_df['transaction_date'])
print(merged_df)

# TODO: Create daily sales aggregation
daily_sales = merged_df.groupby('transaction_date')['total_amount'].sum()
print(daily_sales)

monthly_sales = daily_sales.resample("ME").sum()
print(monthly_sales)

# TODO: Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# TODO: Top-left: Line plot of daily sales
axes[0, 0].plot(daily_sales.index, daily_sales.values)
# TODO: Top-right: Rolling 7-day average
axes[0, 1].plot(daily_sales.index, daily_sales.rolling(window=7).mean().values)
# TODO: Bottom-left: Monthly sales bar chart (use resample('ME') for month-end frequency)
axes[1,0].bar(monthly_sales.index.strftime('%b %Y'), monthly_sales.values)
# TODO: Bottom-right: Sales distribution histogram
axes[1, 1].hist(merged_df['total_amount'])
# TODO: Add titles and labels
axes[0, 0].set_title("Line Plot of Daily Sales Over Time")
axes[0, 0].set_xlabel("Date")
axes[0, 0].set_ylabel("Total Daily Sales ($)")
axes[0, 1].set_title("Line Plot of 7 Day Rolling Average of Daily Sales")
axes[0, 1].set_xlabel("Date")
axes[0, 1].set_ylabel("7 Day Rolling Average Sales ($)")
axes[1, 0].set_title("Bar Chart of Monthly Sales")
axes[1, 0].set_xlabel("Month")
axes[1, 0].set_ylabel("Total Monthly Sales ($)")
axes[1, 1].set_title("Histogram of Sales Distribution")
axes[1, 1].set_xlabel("Total Transaction Amount ($)")
axes[1, 1].set_ylabel("Frequency")
# TODO: Save the plot as 'output/q3_pandas_plots.png'

plt.tight_layout()
plt.savefig('output/q3_pandas_plots.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#     transaction_id customer_id product_id  quantity  unit_price_x  \
# 0            T0001       C0103       P040        10    229.359978
# 1            T0002       C0180       P083         3     75.794677
# 2            T0003       C0093       P042         5    479.387719
# 3            T0004       C0015       P041         5    269.533265
# 4            T0005       C0107       P006         4    128.527714
# ..             ...         ...        ...       ...           ...
# 995          T0996       C0111       P088         2    220.679234
# 996          T0997       C0111       P041         5    417.165094
# 997          T0998       C0034       P017         4     68.746636
# 998          T0999       C0111       P076         4    370.113665
# 999          T1000       C0008       P046         9    270.412908
#
#      total_amount transaction_date store_location customer_name  age gender  \
# 0     2293.599785       2025-10-09          South  Customer 103   23      F
# 1      227.384031       2025-07-21          North  Customer 180   45      M
# 2     2396.938597       2025-06-25           East   Customer 93   70      M
# 3     1347.666324       2025-07-27          South   Customer 15   35      F
# 4      514.110856       2025-08-02          South  Customer 107   39      F
# ..            ...              ...            ...           ...  ...    ...
# 995    441.358467       2025-06-22          South  Customer 111   48      F
# 996   2085.825469       2025-09-26           West  Customer 111   48      F
# 997    274.986543       2025-10-19          North   Customer 34   21      M
# 998   1480.454661       2025-06-06           East  Customer 111   48      F
# 999   2433.716172       2025-06-17          South    Customer 8   55      M
#
#             city state registration_date product_name       category    brand  \
# 0         Dallas    IL        2025-07-26   Product 40       Clothing  Brand E
# 1         Dallas    TX        2025-07-03   Product 83          Books  Brand C
# 2    Los Angeles    OH        2025-09-25   Product 42    Electronics  Brand C
# 3    San Antonio    CA        2025-08-30   Product 41  Home & Garden  Brand A
# 4        Houston    NC        2025-07-04    Product 6       Clothing  Brand B
# ..           ...   ...               ...          ...            ...      ...
# 995       Dallas    PA        2025-09-26   Product 88       Clothing  Brand E
# 996       Dallas    PA        2025-09-26   Product 41  Home & Garden  Brand A
# 997       Dallas    CA        2025-01-13   Product 17  Home & Garden  Brand C
# 998       Dallas    PA        2025-09-26   Product 76          Books  Brand C
# 999      Phoenix    IL        2025-03-04   Product 46    Electronics  Brand B
#
#      unit_price_y  stock_quantity
# 0      230.048472              52
# 1      385.510134              78
# 2      289.744456              70
# 3      293.030410              32
# 4      242.636813              39
# ..            ...             ...
# 995    315.517603              68
# 996    293.030410              32
# 997    125.938794              43
# 998    305.574400              97
# 999    189.731177              73
#
# [1000 rows x 19 columns]
# transaction_date
# 2025-05-03     7300.035699
# 2025-05-04    11726.530834
# 2025-05-05     9031.975210
# 2025-05-06     9948.592231
# 2025-05-07    11495.863090
#                   ...
# 2025-10-25     7355.922852
# 2025-10-26     4815.083898
# 2025-10-27    13892.212172
# 2025-10-28     3167.969257
# 2025-10-29     5480.964325
# Name: total_amount, Length: 180, dtype: float64
# transaction_date
# 2025-05-31    220597.182927
# 2025-06-30    225280.414517
# 2025-07-31    209810.170486
# 2025-08-31    219983.501759
# 2025-09-30    267005.948238
# 2025-10-31    254236.726189
# Freq: ME, Name: total_amount, dtype: float64

# %% [markdown]
# ### Part 3.2: Data Overview Dashboard
#
# **TODO: Create a comprehensive data overview**

# %%
# TODO: Create a figure with multiple subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))

# TODO: Plot 1: Sales by category (bar chart)
axes[0, 0].bar(merged_df['category'].value_counts().index, merged_df['category'].value_counts().values, color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'])
# TODO: Plot 2: Sales by store location (pie chart)
axes[0, 1].pie(merged_df['store_location'].value_counts().values, labels=merged_df['store_location'].value_counts().index, autopct='%1.1f%%', startangle=140, colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'])
# TODO: Plot 3: Age distribution (histogram)
axes[0, 2].hist(merged_df['age'], bins=15, color='lightgreen', edgecolor='black')
# TODO: Plot 4: Quantity vs total_amount scatter
axes[1, 0].scatter(merged_df['quantity'], merged_df['total_amount'], color = "purple", edgecolor='white')
# TODO: Plot 5: Sales over time (line plot)
axes[1, 1].plot(daily_sales.index, daily_sales.values, color = "magenta")
# TODO: Plot 6: Top 10 products by sales (horizontal bar)
top_10_products = merged_df.groupby('product_name')['total_amount'].sum().nlargest(10)
axes[1, 2].barh(top_10_products.index, top_10_products.values, color = "darkgreen", edgecolor = "black")
# TODO: Add titles and customize appearance
axes[0, 0].set_title('Bar Chart of Sales by Category', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Product Category')
axes[0, 0].set_ylabel('Number of Sales')
axes[0, 0].tick_params(axis='x', rotation=45)
axes[0, 0].grid(True, linestyle='--', alpha=0.6)
axes[0, 1].set_title("Pie Chart of Sales by Store Location", fontsize = 14, fontweight = 'bold')
axes[0, 1].set_xlabel('Store Location')
axes[0, 1].grid(True, linestyle='--', alpha=0.6)
axes[0, 2].set_title('Histogram of Age Distribution', fontsize=14, fontweight='bold')
axes[0, 2].set_xlabel('Age(years)')
axes[0, 2].set_ylabel('Frequency')
axes[0, 2].grid(True, linestyle='--', alpha=0.6)
axes[1, 0].set_title('Scatter Plot of Quantity vs Total Amount', fontsize = 14, fontweight = 'bold')
axes[1, 0].set_xlabel('Quantity')
axes[1, 0].grid(True, linestyle='--', alpha=0.6)
axes[1, 0].set_ylabel('Total Amount ($)')
axes[1, 1].set_title('Line Plot of Sales Over Time', fontsize = 14, fontweight = 'bold')
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('Total Sales ($)')
axes[1, 0].set_xlabel('Quantity')
axes[1, 1].grid(True, linestyle='--', alpha=0.6)
axes[1, 2].set_title('Top 10 Products by Sales Amount', fontsize = 14, fontweight = 'bold')
axes[1, 2].set_xlabel('Total Sales Amount ($)')
axes[1, 2].set_ylabel('Product Name')
axes[1, 2].grid(True, linestyle='--', alpha=0.6)
# TODO: Save the plot as 'output/q3_data_overview.png'

plt.tight_layout()
plt.savefig('output/q3_data_overview.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, verify you've created:
#
# - [ ] `output/q1_matplotlib_plots.png` - matplotlib fundamentals
# - [ ] `output/q1_multi_panel.png` - multi-panel visualization
# - [ ] `output/q2_seaborn_plots.png` - seaborn statistical plots
# - [ ] `output/q2_correlation_heatmap.png` - correlation analysis
# - [ ] `output/q3_pandas_plots.png` - pandas plotting
# - [ ] `output/q3_data_overview.png` - data exploration
#
# ## Key Learning Objectives
#
# - Master matplotlib fundamentals for custom plots
# - Create statistical visualizations with seaborn
# - Use pandas plotting for quick exploration
# - Apply visualization best practices
# - Choose appropriate chart types for different data
